# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv('/content/nasa93dem.csv')

# %%
symCols = [col for col in data.columns if col.strip()[0].islower() and data[col].dtypes == 'O']

# %%
data.head()
# Out:
#    idX  centerX  YearX prec flex resl team pmat rely data  ... apex plex ltex  \
# 0    1        2   1979    h    h    h   vh    h    h    l  ...    n    n    h
# 1    2        2   1979    h    h    h   vh    h    h    l  ...    n    n    h
# 2    3        2   1979    h    h    h   vh    h    h    l  ...    n    n    h
# 3    4        2   1979    h    h    h   vh    h    h    l  ...    n    n    h
# 4    5        2   1979    h    h    h   vh    h    h    l  ...    n    n    h
#
#   tool site sced Kloc+ Effort- Defects- Months-
# 0    n    n    l  25.9   117.6      808    15.3
# 1    n    n    l  24.6   117.6      767    15.0
# 2    n    n    l   7.7    31.2      240    10.1
# 3    n    n    l   8.2    36.0      256    10.4
# 4    n    n    l   9.7    25.2      302    11.0
#
# [5 rows x 29 columns]

# %%
le = LabelEncoder()
for sym in symCols:
  tempCol = le.fit_transform(data[sym])
  data[sym] = tempCol.copy()

# %%
data.head()
# Out:
#    idX  centerX  YearX  prec  flex  resl  team  pmat  rely  data  ...  apex  \
# 0    1        2   1979     0     0     0     0     0     0     1  ...     2
# 1    2        2   1979     0     0     0     0     0     0     1  ...     2
# 2    3        2   1979     0     0     0     0     0     0     1  ...     2
# 3    4        2   1979     0     0     0     0     0     0     1  ...     2
# 4    5        2   1979     0     0     0     0     0     0     1  ...     2
#
#    plex  ltex  tool  site  sced  Kloc+  Effort-  Defects-  Months-
# 0     2     0     1     0     0   25.9    117.6       808     15.3
# 1     2     0     1     0     0   24.6    117.6       767     15.0
# 2     2     0     1     0     0    7.7     31.2       240     10.1
# 3     2     0     1     0     0    8.2     36.0       256     10.4
# 4     2     0     1     0     0    9.7     25.2       302     11.0
#
# [5 rows x 29 columns]

# %%
print(symCols)
# Out:
# ['prec', 'flex', 'resl', 'team', 'pmat', 'rely', 'data', 'cplx', 'ruse', 'docu', 'time', 'stor', 'pvol', 'acap', 'pcap', 'pcon', 'apex', 'plex', 'ltex', 'tool', 'site', 'sced']

# %%
data.to_csv('/content/nasa93dem_mod.csv', index=False)
